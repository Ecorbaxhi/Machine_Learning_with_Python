# %% [markdown]
# **QUESTION 2 OF THE HOMEWORK: MY VERSION OF QUESTION 8 AND 10**

# %%
# Question 8

# %%
# (a)

# Use the pd.read_csv() function to read the data into Python. Call the loaded data college.
# Make sure that you have the directory set to the correct location for the data.

# Solution:

# The first thing I need to do is import the library that I will need to process my DataFrame so I import my data in Colab, which will be my Python notebook for this homework.
# Then I run the command pd.read_csv() to read the data present at the path I copied from the file in Google Colab, as shown below.

import pandas as pd
college = pd.read_csv('//College.csv')
college.head()
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
# (b), part 1

# Look at the data used in the notebook by creating and running a new cell with just the code college in it.
# You should notice that the frst column is just the name of each university in a column named something like Unnamed: 0.
# We don’t really want pandas to treat this as data. However, it may be handy to have these names for later.
# Try the following commands and similarly look at the resulting data frames:

college2 = pd.read_csv('//College.csv', index_col=0)
college3 = college.rename({'Unnamed: 0': 'College'},
axis=1)
college3 = college3.set_index('College')

# %%
# (b), part 2

# This has used the frst column in the fle as an index for the data frame. This means that pandas has given each row a name
# corresponding to the appropriate university. Now you should see that the frst data column is Private. Note that the names of
# the colleges appear on the left of the table. We also introduced a new python object above: a dictionary,
# which is specifed by dictionary (key, value) pairs. Keep your modifed version of the data with the following:

college = college3

# %%
# (C)

# Use the describe() method of to produce a numerical summary of the variables in the data set.

# Solution

college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# (d)

# Use the pd.plotting.scatter_matrix() function to produce a scatterplot matrix of the frst columns [Top10perc, Apps, Enroll].
# Recall that you can reference a list C of columns of a data frame A using A[C].

# Solution

pd.plotting.scatter_matrix(college[['Top10perc', 'Apps', 'Enroll']])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %%
# (e)

# Use the boxplot() method of college to produce side-by-side boxplots of Outstate versus Private.

# Solution

college.boxplot(column='Outstate', by='Private')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %%
# (f), part 1

# Create a new qualitative variable, called Elite, by binning the Top10perc variable into two groups based on whether or not the
# proportion of students coming from the top 10% of their high school classes exceeds 50%.

# Solution

college['Elite'] = pd.cut(college['Top10perc'],
[0,50,100],
labels=['No', 'Yes'])

# %%
# (f), part 2

# Use the value_counts() method of college['Elite'] to see how many elite universities there are.

# Solution

college['Elite'].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
# (f), part 3

# Finally, use the boxplot() method again to produce side-by-side boxplots of Outstate versus Elite.

# Solution

college.boxplot(column='Outstate', by='Elite')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %%
# (g)

# Use the plot.hist() method of college to produce some histograms with difering numbers of bins for a few of the quantitative variables.
# The command plt.subplots(2, 2) may be useful: it will divide the plot window into four regions so that four plots can be made simultaneously.
# By changing the arguments you can divide the screen up in other combinations.

# Solution

import matplotlib.pyplot as plt

# %%
# Plot histograms in each subplot with different bin settings


fig, axes = plt.subplots(2, 2, figsize=(12, 8))

college['Accept'].plot.hist(bins=10, ax=axes[0, 0], title='Accept')
college['Top25perc'].plot.hist(bins=15, ax=axes[0, 1], title='Top25perc')
college['Outstate'].plot.hist(bins=20, ax=axes[1, 0], title='Out-of-State Tuition')
college['PhD'].plot.hist(bins=25, ax=axes[1, 1], title='PhD')

plt.tight_layout()
plt.show()

# %%
# (h)

# Continue exploring the data, and provide a brief summary of what you discover.

# Solution

# From the above elaborated data we can confirm that colleges with more top performing students tend to receive more applications and have more enrollments.
# Private colleges charge much higher out-of-state tuition than public ones. Only a small number of colleges are considered “Elite”
# (where over 50% of students are in the top 10%) and these also have higher tuition. Most colleges accept a small number of students,
# and many faculty members hold PhDs.

# %%
# Question 10

# %%
# (a)

# To begin, load in the Boston data set, which is part of the ISLP library.

# Solution:

# I have already imported pandas and run the code so I would only need to load the data

Boston = pd.read_csv('//Boston.csv')

# %%
# (b)

# How many rows are in this data set? How many columns? What do the rows and columns represent?

# Salution:

# We can use the Boston.shape that counts the rows and columns as for below

Boston.shape
# Out:
# (506, 13)

# %%
# (b)

# What do the rows and columns represent?

# Solution:

Boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
# By checking the columns as above we can say that those rappresent specific data regarding crime

# dettails in the city of Boston with regards to different zones or areas that may be rappresented by the rows

# %%
# (c)

# Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your fndings.

# Solution:

import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(Boston[['crim', 'rm', 'lstat', 'medv']])
plt.show()

# %%
# It looks like some variables (like rm and lstat) are good predictors of house price. Others, like crim, are harder to interpret.

# The pairplot helped me see how these variables relate to each other.

# %%
# (d)

# Are any of the predictors associated with per capita crime rate? If so, explain the relationship.


# Solution

# Based on the plots it looks like lstat and medv might be somewhat associated with crime rate.

# Higher lstat could mean higher crim. Higher medv could mean lower crim.

# The relationships are not very strong, but we can see a trend.

# %%
# (e)

# Do any of the suburbs of Boston appear to have particularly high crime rates?

# Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

# Solution

# For checking the highest values in key columns we can use the below

print("Max crime rate:", Boston['crim'].max())
print("Max tax rate:", Boston['tax'].max())
print("Max pupil-teacher ratio:", Boston['ptratio'].max())

# View the full range (min and max)
print("\nCrime rate range:", Boston['crim'].min(), "to", Boston['crim'].max())
print("Tax rate range:", Boston['tax'].min(), "to", Boston['tax'].max())
print("Pupil-teacher ratio range:", Boston['ptratio'].min(), "to", Boston['ptratio'].max())
# Out:
# Max crime rate: 88.9762
# Max tax rate: 711
# Max pupil-teacher ratio: 22.0
#
# Crime rate range: 0.00632 to 88.9762
# Tax rate range: 187 to 711
# Pupil-teacher ratio range: 12.6 to 22.0

# %%
# some suburbs in Boston have particularly high values for crime rate, tax rate, and pupil-teacher ratio.
# These high values are outliers compared to most of the data. The range of values for each predictor
# shows that there is significant diversity among Boston suburbs in terms of safety, taxation, and education resources.

# %%
# (f)

# How many of the suburbs in this data set bound the Charle river?

# Solution

# TO count how many suburbs bound the Charles River
Boston['chas'].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
# (g)

# What is the median pupil-teacher ratio among the towns in this data set?

# Solution

Boston['ptratio'].median()
# Out:
# 19.05

# %%
# (h)

# Which suburb of Boston has lowest median value of owneroccupied homes? What are the values of the other predictors
# for that suburb, and how do those values compare to the overall ranges for those predictors? Comment on your fndings.

# Solution

# To find the lowest median value
min_value = Boston['medv'].min()

# To get the row(s) where medv is equal to the minimum
Boston[Boston['medv'] == min_value]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 398     20.2  30.59   5.0
# 405     20.2  22.98   5.0

# %%
# The suburb with the lowest median home value also has poor values for many other predictors, such as high crime,
# low number of rooms, and high student-to-teacher ratio. This suggests that these factors negatively impact housing value,
# and they are likely connected.

# %%
# (i)

# In this data set, how many of the suburbs average more than seven rooms per dwelling?

# Solution

more_than_7 = Boston[Boston['rm'] > 7]
print("Number of suburbs with more than 7 rooms per dwelling:", more_than_7.shape[0])
# Out:
# Number of suburbs with more than 7 rooms per dwelling: 64

# %%
# More than eight rooms per dwelling?

# Solution

more_than_8 = Boston[Boston['rm'] > 8]
print("Number of suburbs with more than 8 rooms per dwelling:", more_than_8.shape[0])
# Out:
# Number of suburbs with more than 8 rooms per dwelling: 13

# %%
# View the suburbs with more than 8 rooms

# Solution

more_than_8
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 97   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 163  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 224  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 225  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 226  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 232  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 233  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 253  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 257  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 262  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 267  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# ...

# %%
# Comment on the suburbs that average more than eight rooms per dwelling.

# Solution

# Suburbs with more than 8 average rooms per dwelling are rare but stand out as wealthier areas,
# with better education ratios, lower crime, and higher home values.
# This suggests that larger homes are strongly associated with better living conditions and higher real estate value.

# %% [markdown]
# **QUESTION 3 OF HOMEWORK: LLM (CHAT GPT) VERSION OF QUESTION 8 AND 10**

# %%
# Question 8 (a)

# %%
import pandas as pd

# Load the dataset using the specified path
college = pd.read_csv('/College.csv')

# Display the first few rows of the dataset
college.head()
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
# (b)

import pandas as pd

# Step 1: Load the data while keeping the first column as data
college = pd.read_csv('/College.csv')

# Step 2: Load again with the first column used as row index (college names)
college2 = pd.read_csv('/College.csv', index_col=0)

# Step 3: Rename the first column to 'College'
college3 = college.rename({'Unnamed: 0': 'College'}, axis=1)

# Step 4: Set 'College' as the index
college3 = college3.set_index('College')

# Step 5: Keep this final version as the main dataset
college = college3

# Optional: Display the first few rows to confirm the structure
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
# (c)

college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# (d)

import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# Select the columns of interest
cols = ['Top10perc', 'Apps', 'Enroll']

# Create the scatterplot matrix
scatter_matrix(college[cols], figsize=(8, 8), diagonal='hist', alpha=0.7)

# Show the plot
plt.show()

# %%
# (e)

import matplotlib.pyplot as plt

# Create side-by-side boxplots of Outstate grouped by Private
college.boxplot(column='Outstate', by='Private', figsize=(8, 6))

# Add a title and labels
plt.title('Out-of-State Tuition by College Type')
plt.suptitle('')  # Hides the automatic subtitle
plt.xlabel('Private College')
plt.ylabel('Out-of-State Tuition')

# Show the plot
plt.show()

# %%
# (f)

import pandas as pd
import matplotlib.pyplot as plt

# Create the 'Elite' variable: 'Yes' if Top10perc > 50, otherwise 'No'
college['Elite'] = pd.cut(college['Top10perc'],
                          bins=[0, 50, 100],
                          labels=['No', 'Yes'])

# See how many elite vs non-elite universities there are
elite_counts = college['Elite'].value_counts()
print(elite_counts)

# Create side-by-side boxplots of Outstate tuition by Elite status
college.boxplot(column='Outstate', by='Elite', figsize=(8, 6))

# Add a title and labels
plt.title('Out-of-State Tuition by Elite Status')
plt.suptitle('')  # Remove default subtitle
plt.xlabel('Elite')
plt.ylabel('Out-of-State Tuition')

# Show the plot
plt.show()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
# (g)

import matplotlib.pyplot as plt

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Adjust layout
plt.tight_layout(pad=4.0)

# Plot histograms with different bins
college['Apps'].plot.hist(bins=30, ax=axes[0, 0], color='skyblue', edgecolor='black')
axes[0, 0].set_title('Applications Received')

college['Accept'].plot.hist(bins=25, ax=axes[0, 1], color='lightgreen', edgecolor='black')
axes[0, 1].set_title('Applicants Accepted')

college['Enroll'].plot.hist(bins=20, ax=axes[1, 0], color='salmon', edgecolor='black')
axes[1, 0].set_title('New Students Enrolled')

college['Outstate'].plot.hist(bins=15, ax=axes[1, 1], color='orange', edgecolor='black')
axes[1, 1].set_title('Out-of-State Tuition')

# Show the plots
plt.show()

# %%
# (h)

# Elite and Private schools tend to be more expensive.

# Most colleges are not elite, based on the Top10perc criterion.

# Application and enrollment numbers are skewed, with a few colleges standing out as much larger.

# There’s potential to cluster schools based on cost, size, and selectivity.

# %%
# QUESTION 10 (a)

# %%
import pandas as pd

# Load the dataset using the provided path
df_boston = pd.read_csv('/Boston.csv')

# Display the first few rows
df_boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
# (b)

# The Boston housing dataset has:

# 506 rows

# 13 columns

# What do they represent?
# Rows: Each row corresponds to a suburb (tract) in the Boston area.

# Columns: Each column is a variable describing a feature of that suburb, including housing characteristics,
# crime rate, accessibility, and pricing.

# %%
# (c)

import seaborn as sns
import matplotlib.pyplot as plt

# Reuse the selected subset of predictor columns
selected_columns = ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']

# Create pairwise scatterplots
sns.pairplot(df_boston[selected_columns], corner=True, plot_kws={'alpha': 0.5, 's': 15})
plt.suptitle("Pairwise Scatterplots of Selected Predictors", y=1.02)
plt.tight_layout()
plt.show()

# %%
# (d)

# Several predictors are associated with the per capita crime rate in the Boston dataset.
# Notably, rad (access to highways) and tax (property tax rate) show strong positive correlations with crime,
# suggesting that areas with better infrastructure may also experience higher crime.
# Similarly, higher values of lstat (percentage of lower-status population), nox (pollution), and indus (industrial activity)
# are linked to increased crime rates. In contrast, variables like dis (distance from employment centers), rm (number of rooms),
# and medv (median home value) are negatively correlated with crime, indicating that wealthier
# and more suburban neighborhoods tend to have lower crime rates.

# %%
# (e)

# Yes, some suburbs show unusually high values. The crime rate (crim) ranges from as low as 0.006 to as high as 88.98,
# indicating a few areas have exceptionally high crime. Tax rates (tax) vary between 187 and 711,
# with some suburbs facing much higher property taxes than others. For ptratio (pupil–teacher ratio),
# the values range from 12.6 to 22.0, showing that some schools are more crowded.
# These wide ranges suggest notable differences in neighborhood conditions across the Boston area.

# %%
# (f)

# Count how many suburbs have 'chas' == 1 (i.e., they bound the Charles River)
charles_river_count = df_boston['chas'].value_counts().get(1, 0)

# Display the result
charles_river_count
# Out:
# np.int64(35)

# %%
# (g)

# # Calculate the median pupil-teacher ratio
median_ptratio = df_boston['ptratio'].median()
print("Median Pupil-Teacher Ratio:", median_ptratio)
# Out:
# Median Pupil-Teacher Ratio: 19.05

# %%
# The median pupil–teacher ratio among the towns in the dataset is 19.05. This means that half of the towns
# have a pupil–teacher ratio below 19.05 and half have a higher ratio, indicating moderate classroom crowding on average. ​

# %%
# (h)

# Find the suburb with the lowest median value of owner-occupied homes
min_medv_index = df_boston['medv'].idxmin()
lowest_medv_row = df_boston.loc[min_medv_index]

# Get summary statistics for comparison
summary_stats = df_boston.describe()

# %%
# The suburb with the lowest median home value has extremely high crime, pollution, tax rates, and lower
# socioeconomic conditions. It also has older buildings, limited zoning, and maximum highway access,
# reflecting urban disadvantage and environmental stress that likely contribute to low property values.

# %%
# (i)

# Count suburbs with more than 7 and more than 8 rooms per dwelling
more_than_7_rooms = (df_boston['rm'] > 7).sum()
more_than_8_rooms = (df_boston['rm'] > 8).sum()

# Get details of suburbs with more than 8 rooms per dwelling
suburbs_more_than_8 = df_boston[df_boston['rm'] > 8]

# %%
# Suburbs with more than 8 rooms tend to have low crime rates, low pollution, high zoning,
# and low pupil–teacher ratios. They also have very low lstat values (indicating wealthier populations)
# and high median home values, averaging over $44,000 — with many hitting the dataset's max of $50,000.
# These are clearly some of the most affluent neighborhoods in the dataset.

# %% [markdown]
# **QUESTION 4 OF HOMEWORK COMPARISION OF THE CODE**

# %%
# Generally speaking the LLM (chat GPT) is making some errors in finding the correct path also after my confirmation of the path
# Also very interesting that Chat GPT could find some answers and conclusions without running the code as it seems like it has already
# learned from similar DataSets used previoulsy from other users or found the solutions on the web that may not always be acurate
# I have to put the imput in a different way asking for the code in order to obtain the code as for the exercise.
# As for the coding and explanations these are very long and detailed, sometimes creating confusion
# Often after running the code Chat GPT was not showing the result by printing it, and was giving by text the answer of the question

# In general chat GPT has more specific and correct code compared to mine. Are more complete and could search more features.
# Anyway the code was more precise and accurate than mine with deeper research and better interpretation of all the data.

# Some code that I did not understand are under point f of exercise 8 and c and point d of exercise 10
# As for point f of 8, there was too much code (as for below) when the plotbox result was the same as the one I obtained with few code.
#plt.title('Out-of-State Tuition by Elite Status')
#plt.suptitle('')  # Remove default subtitle
#plt.xlabel('Elite')
#plt.ylabel('Out-of-State Tuition')

# Then I learned that most of the new code was actually needed to refine the blotbox and make it more easy to understand.

# As for point c of exercise 10 there were way too many graphs that created conusion. As an effect of c also point d explanation was difficult to understand.

# There seem to be some hallucinations probably coming from the fact that the llm has already used similar datasets in the past and it's using the previous
# results as correct for my DataSet giving the answers for granted to be correct.
